# %% [markdown]
# # Biopharma exploration
#
# Scratch space for exploring pulled EDGAR / ClinicalTrials.gov / FDA data before it graduates into `build_signals.py` / `backtest.py`. Not run as part of any pipeline.

# %%
import sys
sys.path.append("../..")

from biopharma import pull_data, build_signals, backtest
from shared import edgar, fda, validate
