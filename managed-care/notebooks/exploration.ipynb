# %% [markdown]
# # Managed-care exploration
#
# Scratch space for exploring pulled EDGAR / CMS Medicare Advantage / medical-cost-ratio data before it graduates into `build_signals.py` / `backtest.py`. Not run as part of any pipeline.
#
# Note: this subsector's folder name has a hyphen, so its modules can't be imported as a package with `import managed-care` (invalid Python syntax). This notebook instead adds the folder itself to `sys.path` and imports the sibling modules directly.

# %%
import sys
sys.path.append("..")   # managed-care/ itself, for pull_data/build_signals/backtest
sys.path.append("../..")  # repo root, for shared/

import pull_data, build_signals, backtest
from shared import edgar, cms, validate
