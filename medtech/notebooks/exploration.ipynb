# %% [markdown]
# # Medtech exploration
#
# Scratch space for exploring pulled EDGAR / CMS / FDA data before it graduates into `build_signals.py` / `backtest.py`. Not run as part of any pipeline.

# %%
import sys
sys.path.append("../..")

from medtech import pull_data, build_signals, backtest
from shared import edgar, cms, fda, validate
